# %% [markdown]
# # Read Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import OrdinalEncoder

# %% [markdown]
# # LOAD DATA

# %%
hotel_data = pd.read_csv("./first inten project.csv")
hotel_data.head()
# Out:
#   Booking_ID  number of adults  number of children  number of weekend nights  \
# 0   INN00001                 1                   1                         2
# 1   INN00002                 1                   0                         1
# 2   INN00003                 2                   1                         1
# 3   INN00004                 1                   0                         0
# 4   INN00005                 1                   0                         1
#
#    number of week nights  type of meal  car parking space    room type  \
# 0                      5   Meal Plan 1                  0  Room_Type 1
# 1                      3  Not Selected                  0  Room_Type 1
# 2                      3   Meal Plan 1                  0  Room_Type 1
# 3                      2   Meal Plan 1                  0  Room_Type 1
# 4                      2  Not Selected                  0  Room_Type 1
#
#    lead time market segment type  repeated  P-C  P-not-C  average price   \
# ...

# %%
hotel_data.describe()
# Out:
#        number of adults  number of children  number of weekend nights  \
# count      36285.000000        36285.000000              36285.000000
# mean           1.844839            0.105360                  0.810693
# std            0.518813            0.402704                  0.870590
# min            0.000000            0.000000                  0.000000
# 25%            2.000000            0.000000                  0.000000
# 50%            2.000000            0.000000                  1.000000
# 75%            2.000000            0.000000                  2.000000
# max            4.000000           10.000000                  7.000000
#
#        number of week nights  car parking space     lead time      repeated  \
# count           36285.000000       36285.000000  36285.000000  36285.000000
# mean                2.204602           0.030977     85.239851      0.025630
# std                 1.410946           0.173258     85.938796      0.158032
# ...

# %%
hotel_data.dropna()
# Out:
#       Booking_ID  number of adults  number of children  \
# 0       INN00001                 1                   1
# 1       INN00002                 1                   0
# 2       INN00003                 2                   1
# 3       INN00004                 1                   0
# 4       INN00005                 1                   0
# ...          ...               ...                 ...
# 36280   INN36282                 2                   0
# 36281   INN36283                 2                   0
# 36282   INN36284                 2                   0
# 36283   INN36285                 3                   0
# 36284   INN36286                 2                   0
#
#        number of weekend nights  number of week nights  type of meal  \
# 0                             2                      5   Meal Plan 1
# 1                             1                      3  Not Selected
# 2                             1                      3   Meal Plan 1
# ...

# %%
hotel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31853 entries, 0 to 36283
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Booking_ID                31853 non-null  object
#  1   number of adults          31853 non-null  int64
#  2   number of children        31853 non-null  int64
#  3   number of weekend nights  31853 non-null  int64
#  4   number of week nights     31853 non-null  int64
#  5   type of meal              31853 non-null  object
#  6   car parking space         31853 non-null  int64
#  7   room type                 31853 non-null  object
#  8   lead time                 31853 non-null  int64
#  9   market segment type       31853 non-null  object
#  10  repeated                  31853 non-null  int64
#  11  P-C                       31853 non-null  int64
#  12  P-not-C                   31853 non-null  int64
#  13  average price             31853 non-null  float64
# ...

# %% [markdown]
# # Visulization

# %%
sns.displot(data=hotel_data, y="number of adults", col="booking status")

# %%
sns.kdeplot(data=hotel_data, x="average price ", hue="booking status")
# Out:
# <Axes: xlabel='average price ', ylabel='Density'>

# %%
df = hotel_data["number of children"] + hotel_data["number of adults"]

# %%
sns.relplot(data=hotel_data, y="room type", x="average price ", hue="booking status")

# %%
sns.relplot(data=hotel_data, y="type of meal", x="average price ", hue="booking status")

# %%
sns.relplot(data=hotel_data, y="special requests", x="average price ", hue="booking status")

# %%
sns.relplot(data=hotel_data, y="lead time", x="average price ", hue="booking status")

# %%
sns.displot(data=hotel_data, x="market segment type",col="booking status")

# %%
sns.displot(data=hotel_data, x="P-not-C", col="booking status")

# %%
sns.displot(data=hotel_data, x="P-C", col="booking status")

# %%
sns.boxplot(data=hotel_data, y="booking status" ,x="average price ", orient="h")
# Out:
# <Axes: xlabel='average price ', ylabel='booking status'>

# %%
sns.boxplot(data=hotel_data, y="booking status" ,x="lead time", orient="h")
# Out:
# <Axes: xlabel='lead time', ylabel='booking status'>

# %%
sns.boxplot(data=hotel_data, y="booking status" ,x="market segment type", orient="h")
# Out:
# <Axes: xlabel='market segment type', ylabel='booking status'>

# %% [markdown]
# # Delete Outliers

# %%
def remove_outliers(df,columns,n_std):
    for col in columns:
        print('Working on column: {}'.format(col))
        
        mean = df[col].mean()
        sd = df[col].std()
        
        df = df[(df[col] <= mean+(n_std*sd))]
        
    return df

# %%
numrical_features = ["number of adults","number of children", "number of weekend nights",
                     "number of week nights", "car parking space", "lead time","repeated",
                     "P-C","P-not-C", "average price ","special requests"]
hotel_data = remove_outliers(hotel_data,numrical_features,3)
# Out:
# Working on column: number of adults
# Working on column: number of children
# Working on column: number of weekend nights
# Working on column: number of week nights
# Working on column: car parking space
# Working on column: lead time
# Working on column: repeated
# Working on column: P-C
# Working on column: P-not-C
# Working on column: average price
# Working on column: special requests

# %% [markdown]
# # Get output label

# %%
hotel_data["booking status"] = hotel_data["booking status"].replace("Not_Canceled", 0)
hotel_data["booking status"] = hotel_data["booking status"].replace("Canceled", 1)
y_output = hotel_data.pop("booking status")

# %%
y_output = np.array(y_output).reshape(-1, 1)
y_output
# Out:
# array([[0],
#        [0],
#        [1],
#        ...,
#        [0],
#        [0],
#        [0]])

# %% [markdown]
# # Get features

# %%
catgorical_features = ["type of meal","room type","market segment type"]

features = []
for cat in catgorical_features:
    vocab = hotel_data[cat].unique().reshape(-1,1)
    enc = OrdinalEncoder()
    enc.fit(vocab)
    features.append(enc.transform(np.array(hotel_data[cat]).reshape(-1,1)))

for num in numrical_features:
    features.append(np.array(hotel_data[num]).reshape(-1,1))

# %%
features = np.concatenate(features, axis=1)

# %% [markdown]
# # data_Normlization

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(features)
features = scaler.transform(features)

# %% [markdown]
# # Data Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features, y_output, test_size=0.33, random_state=42)
